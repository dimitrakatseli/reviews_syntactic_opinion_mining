# %%
import spacy

# %%
from spacy.lang.el.stop_words import STOP_WORDS

# %%
nlp = spacy.load('el_core_news_sm')

# %%
review = nlp(u"""
Είμαι κάτοχος του τηλεφώνου εδώ και περίπου μία εβδομάδα και μπορώ να πω πως στην mid range κατηγορία τιμής δεν υπάρχει ανταγωνιστής. Η κάμερα του είναι εξαιρετική σε βίντεο και σε φωτογραφία, το ηχείο ικανοποιητικό με καλή ποιότητα και υψηλή ένταση, η gaming εμπειρία είναι τρομερή και σε γενικές γραμμές το τηλέφωνό είναι ένα τέρας. Μικρό παράπονο έχω από την μπαταρία η οποία είναι λίγο μικρή. Αν ψάχνετε μια νέα α συσκευή σε αυτό το μπάτζετ βάλτε το xiaomi mi a2 καλά στον νου σας.""")

# %%
#nlp.vocab["έχω"].is_stop

# %%
for word in review.ents:
    print(word.text,word.label_)

# %%
for token in review:
        print(token.text, token.pos_, token.dep_)
# Out:
#  SPACE
# Είμαι AUX cop
# κάτοχος NOUN ROOT
# του DET det
# τηλεφώνου PRON nmod
# εδώ ADV advmod
# και CCONJ cc
# περίπου ADV advmod
# μία NUM det
# εβδομάδα NOUN obl
# και CCONJ cc
# μπορώ VERB conj
# να PART aux
# πω VERB xcomp
# πως SCONJ mark
# στην ADJ advmod
# mid DET nummod
# range ADJ amod
# κατηγορία NOUN nsubj
# τιμής NOUN nmod
# δεν PART advmod
# υπάρχει VERB ccomp
# ανταγωνιστής NOUN nsubj
# . PUNCT punct
# Η DET det
# κάμερα NOUN nsubj
# του PRON nmod
# είναι AUX cop
# εξαιρετική ADJ advmod
# σε ADP case
# βίντεο X nmod
# και CCONJ cc
# σε ADP case
# φωτογραφία NOUN conj
# , PUNCT punct
# το DET det
# ηχείο NOUN nsubj
# ικανοποιητικό ADJ amod
# με ADP case
# καλή ADJ amod
# ποιότητα NOUN nmod
# και CCONJ cc
# υψηλή ADJ amod
# ένταση NOUN conj
# , PUNCT punct
# η DET det
# gaming X amod
# εμπειρία NOUN nsubj
# είναι AUX cop
# τρομερή ADJ acl:relcl
# και CCONJ cc
# σε ADP case
# γενικές ADJ amod
# γραμμές NOUN obl
# το DET det
# τηλέφωνό NOUN nsubj
# είναι AUX cop
# ένα DET det
# τέρας NOUN conj
# . PUNCT punct
# Μικρό ADJ amod
# παράπονο NOUN nsubj
# έχω VERB acl:relcl
# από ADP case
# την DET det
# μπαταρία NOUN obl
# η DET det
# οποία PRON nsubj
# είναι AUX cop
# λίγο ADV advmod
# μικρή ADJ acl:relcl
# . PUNCT punct
# Αν SCONJ mark
# ψάχνετε VERB advcl
# μια DET det
# νέα ADJ amod
# α NOUN nmod
# συσκευή NOUN obj
# σε ADP case
# αυτό PRON det
# το DET det
# μπάτζετ ADJ obl
# βάλτε VERB advcl
# το DET det
# xiaomi PRON obj
# mi NUM flat
# a2 X flat
# καλά ADV advmod
# στον ADJ advmod
# νου NOUN obl
# σας PRON nmod
# . PUNCT punct

# %%
spacy.explain('ccomp')
# Out:
# 'clausal complement'

# %%
from spacy import displacy

# %%
#displacy.render(review,style="dep",jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="el" id="7dfb33f3d0b94633909d0b8c0bc1c759-0" class="displacy" width="15100" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Είμαι</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">κάτοχος</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">του</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">τηλεφώνου</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">εδώ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">και</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">περίπου</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">μία</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">εβδομάδα</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">και</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">μπορώ</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">να</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">πω</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">πως</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">στην</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">mid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">range</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">κατηγορία</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">τιμής</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">δεν</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">υπάρχει</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">ανταγωνιστής.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Η</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">κάμερα</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">του</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">είναι</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">εξαιρετική</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">σε</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">βίντεο</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">X</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">και</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCol

# %%
for token in review.noun_chunks:
    print(token.root.text,"connector_text:",token.root.head.text)
# Out:
# κάτοχος connector_text: κάτοχος
# εβδομάδα connector_text: κάτοχος
# κατηγορία connector_text: υπάρχει
# ανταγωνιστής connector_text: υπάρχει
# κάμερα connector_text: εξαιρετική
# ηχείο connector_text: τρομερή
# εμπειρία connector_text: τρομερή
# γραμμές connector_text: τρομερή
# τηλέφωνό connector_text: τέρας
# παράπονο connector_text: έχω
# μπαταρία connector_text: έχω
# οποία connector_text: μικρή
# συσκευή connector_text: ψάχνετε
# xiaomi connector_text: βάλτε
# νου connector_text: βάλτε

# %%
for token in review :
    if token.pos_ =="NOUN" and token.dep_ !='obl' and token.dep_ !='obl' and token.is_stop==False:
      print(token.text, token.pos_, token.dep_)
# Out:
# κάτοχος NOUN ROOT
# κατηγορία NOUN nsubj
# τιμής NOUN nmod
# ανταγωνιστής NOUN nsubj
# κάμερα NOUN nsubj
# φωτογραφία NOUN conj
# ηχείο NOUN nsubj
# ποιότητα NOUN nmod
# ένταση NOUN conj
# εμπειρία NOUN nsubj
# τηλέφωνό NOUN nsubj
# τέρας NOUN conj
# παράπονο NOUN nsubj
# α NOUN nmod
# συσκευή NOUN obj

# %%
for token in review:
    if(((((token.dep_=='advmod') or (token.dep_=='amod') or (token.dep_=='ADJ') or (token.dep_== 'nsubj' ))and (token.is_stop==False))   and (token.head.pos_ !='PUNCT')) and (token.head.pos_!='NUM') ):#and  (token.head.pos_ !='VERB') 
            print(token.text, token.dep_, token.head.text, token.head.pos_,
            [child for child in token.children])
# Out:
# range amod κατηγορία NOUN [στην, mid]
# κατηγορία nsubj υπάρχει VERB [range, τιμής]
# ανταγωνιστής nsubj υπάρχει VERB []
# κάμερα nsubj εξαιρετική ADJ [Η, του]
# εξαιρετική advmod κάτοχος NOUN [κάμερα, είναι, βίντεο, ,]
# ηχείο nsubj τρομερή ADJ [το, ικανοποιητικό, ποιότητα]
# ικανοποιητικό amod ηχείο NOUN []
# καλή amod ποιότητα NOUN []
# υψηλή amod ένταση NOUN []
# gaming amod εμπειρία NOUN [η]
# εμπειρία nsubj τρομερή ADJ [,, gaming]
# γενικές amod γραμμές NOUN []
# τηλέφωνό nsubj τέρας NOUN [το]
# Μικρό amod παράπονο NOUN []
# παράπονο nsubj έχω VERB [Μικρό]
# νέα amod συσκευή NOUN []
